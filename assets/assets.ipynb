# %%
import pandas as pd

df = pd.read_csv("assets.csv")
print(df.shape)
# Out:
# (10200, 14)

# %%
df.head()
# Out:
#   Symbol                  Company Name         Short Name  \
# 0      A     Agilent Technologies Inc.            Agilent
# 1     AA             Alcoa Corporation              Alcoa
# 2    AAC             AAC Holdings Inc.                AAC
# 3    AAL  American Airlines Group Inc.  American Airlines
# 4    AAN                  Aaron's Inc.            Aaron's
#
#                          Industry  \
# 0  Medical Diagnostics & Research
# 1                 Metals & Mining
# 2           Health Care Providers
# 3                        Airlines
# 4        Consulting & Outsourcing
#
#                                          Description  Website Logo  \
# 0  Agilent Technologies Inc is engaged in life sc...           NaN
# 1  Alcoa Corp is an integrated aluminum company. ...           NaN
# 2  AAC Holdings Inc provides inpatient and outpat...           NaN
# 3  American Airlines Group Inc operates over 6,00...           NaN
# 4  Aaron's Inc is a retailer of furniture, consum...           NaN
#
#                       CEO                 Exchange    Market Cap  \
# 0     Michael R. McMullen  New York Stock Exchange  2.421807e+10
# 1  Roy Christopher Harvey  New York Stock Exchange  5.374967e+09
# 2   Michael T. Cartwright  New York Stock Exchange  6.372010e+07
# 3       W. Douglas Parker     Nasdaq Global Select  1.694019e+10
# 4        John W. Robinson  New York Stock Exchange  3.677543e+09
#
#             Sector            Tag 1                      Tag 2  \
# 0       Healthcare       Healthcare     Diagnostics & Research
# 1  Basic Materials  Basic Materials                   Aluminum
# 2       Healthcare       Healthcare               Medical Care
# 3      Industrials      Industrials                   Airlines
# 4      Industrials      Industrials  Rental & Leasing Services
#
#                             Tag 3 OTC
# 0  Medical Diagnostics & Research   F
# 1                 Metals & Mining   F
# 2           Health Care Providers   F
# 3                             NaN   F
# 4        Consulting & Outsourcing   F

# %%
import yfinance as yf

# %%
msft = yf.Ticker("MSFT")

# %%
print(msft.info)
# Out:
# {'address1': 'One Microsoft Way', 'city': 'Redmond', 'state': 'WA', 'zip': '98052-6399', 'country': 'United States', 'phone': '425 882 8080', 'fax': '425 706 7329', 'website': 'https://www.microsoft.com', 'industry': 'Software—Infrastructure', 'sector': 'Technology', 'longBusinessSummary': 'Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. The More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; and Windows Internet of Things. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.', 'fullTimeEmployees': 221000, 'companyOfficers': [{'maxAge': 1, 'name': 'Mr. Satya  Nadella', 'age': 55, 'title': 'Chairman & CEO', 'yearBorn': 1967, 'fiscalYear': 2022, 'totalPay': 12676750, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Bradford L. Smith LCA', 'age': 63, 'title': 'Pres & Vice Chairman', 'yearBorn': 1959, 'fiscalYear': 2022, 'totalPay': 4655274, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Amy E. Hood', 'age': 50, 'title': 'Exec. VP & CFO', 'yearBorn': 1972, 'fiscalYear': 2022, 'totalPay': 4637915, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Judson  Althoff', 'age': 49, 'title': 'Exec. VP & Chief Commercial Officer', 'yearBorn': 1973, 'fiscalYear': 2022, 'totalPay': 4428268, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Christopher David Young', 'age': 50, 'title': 'Exec. VP of Bus. Devel., Strategy & Ventures', 'yearBorn': 1972, 'fiscalYear': 2022, 'totalPay': 4588876, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Ms. Alice L. Jolla', 'age': 55, 'title': 'Corp. VP & Chief Accounting Officer', 'yearBorn': 1967, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Brett  Iversen', 'title': 'Gen. Mang. of Investor Relations', 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Frank X. Shaw', 'title': 'Corp. VP for Corp. Communications', 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Christopher C. Capossela', 'age': 52, 'title': 'Exec. VP & Chief Marketing Officer', 'yearBorn': 1970, 'exercisedValue': 0, 'unexercisedValue': 0}, {'maxAge': 1, 'name': 'Mr. Keith Ranger Dolliver Esq.', 'title' ...

# %%
print(msft.info['longBusinessSummary'])
# Out:
# Microsoft Corporation develops, licenses, and supports software, services, devices, and solutions worldwide. The company operates in three segments: Productivity and Business Processes, Intelligent Cloud, and More Personal Computing. The Productivity and Business Processes segment offers Office, Exchange, SharePoint, Microsoft Teams, Office 365 Security and Compliance, Microsoft Viva, and Skype for Business; Skype, Outlook.com, OneDrive, and LinkedIn; and Dynamics 365, a set of cloud-based and on-premises business solutions for organizations and enterprise divisions. The Intelligent Cloud segment licenses SQL, Windows Servers, Visual Studio, System Center, and related Client Access Licenses; GitHub that provides a collaboration platform and code hosting service for developers; Nuance provides healthcare and enterprise AI solutions; and Azure, a cloud platform. It also offers enterprise support, Microsoft consulting, and nuance professional services to assist customers in developing, deploying, and managing Microsoft server and desktop solutions; and training and certification on Microsoft products. The More Personal Computing segment provides Windows original equipment manufacturer (OEM) licensing and other non-volume licensing of the Windows operating system; Windows Commercial, such as volume licensing of the Windows operating system, Windows cloud services, and other Windows commercial offerings; patent licensing; and Windows Internet of Things. It also offers Surface, PC accessories, PCs, tablets, gaming and entertainment consoles, and other devices; Gaming, including Xbox hardware, and Xbox content and services; video games and third-party video game royalties; and Search, including Bing and Microsoft advertising. The company sells its products through OEMs, distributors, and resellers; and directly through digital marketplaces, online stores, and retail stores. Microsoft Corporation was founded in 1975 and is headquartered in Redmond, Washington.

# %%
def getDescription(ticker):
    company = yf.Ticker(ticker)
    return company.info['longBusinessSummary']

# %%
getDescription('AAPL')
# Out:
# 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was incorporated in 1977 and is headquartered in Cupertino, California.'

# %%
getDescription('TSLA')
# Out:
# 'Tesla, Inc. designs, develops, manufactures, leases, and sells electric vehicles, and energy generation and storage systems in the United States, China, and internationally. It operates in two segments, Automotive, and Energy Generation and Storage. The Automotive segment offers electric vehicles, as well as sells automotive regulatory credits; and non-warranty after-sales vehicle, used vehicles, retail merchandise, and vehicle insurance services. This segment also provides sedans and sport utility vehicles through direct and used vehicle sales, a network of Tesla Superchargers, and in-app upgrades; purchase financing and leasing services; services for electric vehicles through its company-owned service locations and Tesla mobile service technicians; and vehicle limited warranties and extended service plans. The Energy Generation and Storage segment engages in the design, manufacture, installation, sale, and leasing of solar energy generation and energy storage products, and related services to residential, commercial, and industrial customers and utilities through its website, stores, and galleries, as well as through a network of channel partners; and provision of service and repairs to its energy product customers, including under warranty, as well as various financing options to its solar customers. The company was formerly known as Tesla Motors, Inc. and changed its name to Tesla, Inc. in February 2017. Tesla, Inc. was incorporated in 2003 and is headquartered in Austin, Texas.'

# %%
df.loc[:,'Description']
# Out:
# 0        Agilent Technologies Inc is engaged in life sc...
# 1        Alcoa Corp is an integrated aluminum company. ...
# 2        AAC Holdings Inc provides inpatient and outpat...
# 3        American Airlines Group Inc operates over 6,00...
# 4        Aaron's Inc is a retailer of furniture, consum...
#                                ...
# 10195                                                  NaN
# 10196                                                  NaN
# 10197    Zymeworks Inc is a clinical-stage biopharmaceu...
# 10198    Zynerba Pharmaceuticals Inc together with its ...
# 10199                                                  NaN
# Name: Description, Length: 10200, dtype: object

# %%
for symbol in df.tail()['Symbol']:
    ticker = yf.Ticker(symbol)
    info = ticker.info
    description = info['longBusinessSummary']
    df.loc[df['Symbol'] == symbol, 'Description'] = description

# %%
df.tail()
# Out:
#       Symbol                            Company Name               Short Name  \
# 10195   ZVIA                               Zevia PBC                      NaN
# 10196    ZWS  Zurn Elkay Water Solutions Corporation                      NaN
# 10197   ZYME                          Zymeworks Inc.                Zymeworks
# 10198   ZYNE            Zynerba Pharmaceuticals Inc.  Zynerba Pharmaceuticals
# 10199   ZYXI                Zynex, Inc. Common Stock                      NaN
#
#             Industry                                        Description  \
# 10195            NaN  Zevia PBC, a beverage company, develops, marke...
# 10196            NaN  Zurn Elkay Water Solutions Corporation engages...
# 10197  Biotechnology  Zymeworks Inc., a clinical-stage biopharmaceut...
# 10198  Biotechnology  Zynerba Pharmaceuticals, Inc. operates as a cl...
# 10199            NaN  Zynex, Inc., together with its subsidiaries, d...
#
#        Website Logo            CEO                 Exchange   Market Cap  \
# 10195           NaN            NaN                      NaN          NaN
# 10196           NaN            NaN                      NaN          NaN
# 10197           NaN    Ali Tehrani  New York Stock Exchange  504287824.0
# 10198           NaN  Armando Anido     NASDAQ Global Market   99944370.0
# 10199           NaN            NaN                      NaN          NaN
#
#            Sector       Tag 1          Tag 2 Tag 3 OTC
# 10195         NaN         NaN            NaN   NaN   F
# 10196         NaN         NaN            NaN   NaN   F
# 10197  Healthcare  Healthcare  Biotechnology   NaN   F
# 10198  Healthcare  Healthcare  Biotechnology   NaN   F
# 10199         NaN         NaN            NaN   NaN   F

# %%
df.to_csv('assets.csv', index=False)

# %%
df.head(1000)
# Out:
#     Symbol                            Company Name  \
# 0        A               Agilent Technologies Inc.
# 1       AA                       Alcoa Corporation
# 2      AAC                       AAC Holdings Inc.
# 3      AAL            American Airlines Group Inc.
# 4      AAN                            Aaron's Inc.
# ..     ...                                     ...
# 995   BLDR               Builders FirstSource Inc.
# 996    BLE     BlackRock Municipal Income Trust II
# 997   BLES                 Inspire Global Hope ETF
# 998   BLEU  bleuacacia ltd Class A Ordinary Shares
# 999  BLEUR                   bleuacacia ltd Rights
#
#                               Short Name                        Industry  \
# 0                                Agilent  Medical Diagnostics & Research
# 1                                  Alcoa                 Metals & Mining
# 2                                    AAC           Health Care Providers
# 3                      American Airlines                        Airlines
# 4                                Aaron's        Consulting & Outsourcing
# ..                                   ...                             ...
# 995                 Builders FirstSource              Building Materials
# 996  BlackRock Municipal Income Trust II                Asset Management
# 997                                  NaN                             NaN
# 998                                  NaN                             NaN
# 999                                  NaN                             NaN
#
#                                            Description  Website Logo  \
# 0    Agilent Technologies, Inc. provides applicatio...           NaN
# 1    Alcoa Corporation, together with its subsidiar...           NaN
# 2    Ares Acquisition Corporation does not have sig...           NaN
# 3    American Airlines Group Inc., through its subs...           NaN
# 4    The Aaron's Company, Inc. provides lease-to-ow...           NaN
# ..                                                 ...           ...
# 995  Builders FirstSource Inc is a supplier and man...           NaN
# 996  Blackrock Municipal Income Trust II is a perpe...           NaN
# 997                                                NaN           NaN
# 998                                                NaN           NaN
# 999                                                NaN           NaN
#
#                         CEO                 Exchange    Market Cap  \
# 0       Michael R. McMullen  New York Stock Exchange  2.421807e+10
# 1    Roy Christopher Harvey  New York Stock Exchange  5.374967e+09
# 2     Michael T. Cartwright  New York Stock Exchange  6.372010e+07
# 3         W. Douglas Parker     Nasdaq Global Select  1.694019e+10
# 4          John W. Robinson  New York Stock Exchange  3.677543e+09
# ..                      ...                      ...           ...
# 995            M. Chad Crow     Nasdaq Global Select  1.539609e+09
# 996       John M. Perlowski  New York Stock Exchange  3.263592e+08
# 997                     NaN                      NaN           NaN
# 998                     NaN                      NaN           NaN
# 999                     NaN                      NaN           NaN
#
#                  Sector               Tag 1                      Tag 2  \
# 0            Healthcare          Healthcare     Diagnostics & Research
# 1       Basic Materials     Basic Materials                   Aluminum
# 2            Healthcare          Healthcare               Medical Care
# 3           Industrials         Industrials                   Airlines
# 4           Industrials         Industrials  Rental & Leasing Services
# ..                  ...                 ...                        ...
# 995     Basic Materials     Basic Materials         Building Materials
# 996  Financial Services  Financial Services           Asset Management
# 997                 NaN                 NaN                        NaN
# 998                 NaN                 NaN                        NaN
# 999                 NaN                 NaN                        NaN
#
#                               Tag 3 OTC
# 0    Medical Diagnostics & Research   F
# 1                   Metals & Mining   F
# 2             Health Care Providers   F
# 3                               NaN   F
# 4          Consulting & Outsourcing   F
# ..                              ...  ..
# 995                             NaN   F
# 996                             NaN   F
# 997                             NaN   F
# 998                             NaN   F
# 999                             NaN   F
#
# [1000 rows x 14 columns]

# %%
df[0:100]
# Out:
#    Symbol                          Company Name  \
# 0       A             Agilent Technologies Inc.
# 1      AA                     Alcoa Corporation
# 2     AAC                     AAC Holdings Inc.
# 3     AAL          American Airlines Group Inc.
# 4     AAN                          Aaron's Inc.
# ..    ...                                   ...
# 95   AGEN                           Agenus Inc.
# 96    AGG  iShares Core U.S. Aggregate Bond ETF
# 97    AGI              Alamos Gold Inc. Class A
# 98   AGIO            Agios Pharmaceuticals Inc.
# 99    AGL                   agilon health, inc.
#
#                               Short Name                        Industry  \
# 0                                Agilent  Medical Diagnostics & Research
# 1                                  Alcoa                 Metals & Mining
# 2                                    AAC           Health Care Providers
# 3                      American Airlines                        Airlines
# 4                                Aaron's        Consulting & Outsourcing
# ..                                   ...                             ...
# 95                                Agenus                   Biotechnology
# 96  iShares Core U.S. Aggregate Bond ETF                             NaN
# 97                           Alamos Gold                 Metals & Mining
# 98                          Agios Pharma                   Biotechnology
# 99                                   NaN                             NaN
#
#                                           Description  Website Logo  \
# 0   Agilent Technologies, Inc. provides applicatio...           NaN
# 1   Alcoa Corporation, together with its subsidiar...           NaN
# 2   Ares Acquisition Corporation does not have sig...           NaN
# 3   American Airlines Group Inc., through its subs...           NaN
# 4   The Aaron's Company, Inc. provides lease-to-ow...           NaN
# ..                                                ...           ...
# 95  Agenus Inc., a clinical-stage immuno-oncology ...           NaN
# 96  The index measures the performance of the tota...           NaN
# 97  Alamos Gold Inc. engages in the acquisition, e...           NaN
# 98  Agios Pharmaceuticals, Inc., a biopharmaceutic...           NaN
# 99  agilon health, inc. offers healthcare services...           NaN
#
#                        CEO                 Exchange    Market Cap  \
# 0      Michael R. McMullen  New York Stock Exchange  2.421807e+10
# 1   Roy Christopher Harvey  New York Stock Exchange  5.374967e+09
# 2    Michael T. Cartwright  New York Stock Exchange  6.372010e+07
# 3        W. Douglas Parker     Nasdaq Global Select  1.694019e+10
# 4         John W. Robinson  New York Stock Exchange  3.677543e+09
# ..                     ...                      ...           ...
# 95            Garo H Armen    NASDAQ Capital Market  4.680513e+08
# 96                     NaN                NYSE Arca  5.711667e+10
# 97          John Mccluskey  New York Stock Exchange  1.733238e+09
# 98      David P. Schenkein     Nasdaq Global Select  3.158520e+09
# 99                     NaN                      NaN           NaN
#
#              Sector            Tag 1                      Tag 2  \
# 0        Healthcare       Healthcare     Diagnostics & Research
# 1   Basic Materials  Basic Materials                   Aluminum
# 2        Healthcare       Healthcare               Medical Care
# 3       Industrials      Industrials                   Airlines
# 4       Industrials      Industrials  Rental & Leasing Services
# ..              ...              ...                        ...
# 95       Healthcare       Healthcare              Biotechnology
# 96              NaN              NaN                        NaN
# 97  Basic Materials  Basic Materials                       Gold
# 98       Healthcare       Healthcare              Biotechnology
# 99              NaN              NaN                        NaN
#
#                              Tag 3 OTC
# 0   Medical Diagnostics & Research   F
# 1                  Metals & Mining   F
# 2            Health Care Providers   F
# 3                              NaN   F
# 4         Consulting & Outsourcing   F
# ..                             ...  ..
# 95                             NaN   F
# 96                             NaN   F
# 97                 Metals & Mining   F
# 98                             NaN   F
# 99                             NaN   F
#
# [100 rows x 14 columns]

# %%
for symbol in df[0:100]['Symbol']:
    ticker = yf.Ticker(symbol)
    info = ticker.info
    description = info['longBusinessSummary']
    df.loc[df['Symbol'] == symbol, 'Description'] = description

# %%
df[0:100]
# Out:
#    Symbol                          Company Name  \
# 0       A             Agilent Technologies Inc.
# 1      AA                     Alcoa Corporation
# 2     AAC                     AAC Holdings Inc.
# 3     AAL          American Airlines Group Inc.
# 4     AAN                          Aaron's Inc.
# ..    ...                                   ...
# 95   AGEN                           Agenus Inc.
# 96    AGG  iShares Core U.S. Aggregate Bond ETF
# 97    AGI              Alamos Gold Inc. Class A
# 98   AGIO            Agios Pharmaceuticals Inc.
# 99    AGL                   agilon health, inc.
#
#                               Short Name                        Industry  \
# 0                                Agilent  Medical Diagnostics & Research
# 1                                  Alcoa                 Metals & Mining
# 2                                    AAC           Health Care Providers
# 3                      American Airlines                        Airlines
# 4                                Aaron's        Consulting & Outsourcing
# ..                                   ...                             ...
# 95                                Agenus                   Biotechnology
# 96  iShares Core U.S. Aggregate Bond ETF                             NaN
# 97                           Alamos Gold                 Metals & Mining
# 98                          Agios Pharma                   Biotechnology
# 99                                   NaN                             NaN
#
#                                           Description  Website Logo  \
# 0   Agilent Technologies, Inc. provides applicatio...           NaN
# 1   Alcoa Corporation, together with its subsidiar...           NaN
# 2   Ares Acquisition Corporation does not have sig...           NaN
# 3   American Airlines Group Inc., through its subs...           NaN
# 4   The Aaron's Company, Inc. provides lease-to-ow...           NaN
# ..                                                ...           ...
# 95  Agenus Inc., a clinical-stage immuno-oncology ...           NaN
# 96  The index measures the performance of the tota...           NaN
# 97  Alamos Gold Inc. engages in the acquisition, e...           NaN
# 98  Agios Pharmaceuticals, Inc., a biopharmaceutic...           NaN
# 99  agilon health, inc. offers healthcare services...           NaN
#
#                        CEO                 Exchange    Market Cap  \
# 0      Michael R. McMullen  New York Stock Exchange  2.421807e+10
# 1   Roy Christopher Harvey  New York Stock Exchange  5.374967e+09
# 2    Michael T. Cartwright  New York Stock Exchange  6.372010e+07
# 3        W. Douglas Parker     Nasdaq Global Select  1.694019e+10
# 4         John W. Robinson  New York Stock Exchange  3.677543e+09
# ..                     ...                      ...           ...
# 95            Garo H Armen    NASDAQ Capital Market  4.680513e+08
# 96                     NaN                NYSE Arca  5.711667e+10
# 97          John Mccluskey  New York Stock Exchange  1.733238e+09
# 98      David P. Schenkein     Nasdaq Global Select  3.158520e+09
# 99                     NaN                      NaN           NaN
#
#              Sector            Tag 1                      Tag 2  \
# 0        Healthcare       Healthcare     Diagnostics & Research
# 1   Basic Materials  Basic Materials                   Aluminum
# 2        Healthcare       Healthcare               Medical Care
# 3       Industrials      Industrials                   Airlines
# 4       Industrials      Industrials  Rental & Leasing Services
# ..              ...              ...                        ...
# 95       Healthcare       Healthcare              Biotechnology
# 96              NaN              NaN                        NaN
# 97  Basic Materials  Basic Materials                       Gold
# 98       Healthcare       Healthcare              Biotechnology
# 99              NaN              NaN                        NaN
#
#                              Tag 3 OTC
# 0   Medical Diagnostics & Research   F
# 1                  Metals & Mining   F
# 2            Health Care Providers   F
# 3                              NaN   F
# 4         Consulting & Outsourcing   F
# ..                             ...  ..
# 95                             NaN   F
# 96                             NaN   F
# 97                 Metals & Mining   F
# 98                             NaN   F
# 99                             NaN   F
#
# [100 rows x 14 columns]

# %%
df.to_csv('assets.csv', index=False)
